# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# %matplotlib inline

from logistic_model import LogisticModel, SimpleLogisticRegression
from logistic_regression import LogisticRegression, LogisticRegressionOvR
from preprocess import preprocess_data

np.set_printoptions(precision=2)

# we set the random seed to make our results deterministic
# (same results across runs)
# on définit un noyau pour rendre nos résultats déterministes
# (pour que tout le monde ait les mêmes resultats.)
np.random.seed(2)

# %% [markdown]
# Loading data

# %%
raw_train_data = pd.read_csv("../data/train.csv")
raw_test_data = pd.read_csv("../data/test.csv")

# %% [markdown]
# Preprocessing

# %%
train_data = preprocess_data(raw_df=raw_train_data)
train_data
# Out:
# array([[ 21.71, 275.  ,  78.91, ...,   0.  ,   1.  ,   0.  ],
#        [ 21.71, 275.  ,  78.91, ...,   0.  ,   1.  ,   0.  ],
#        [ 21.47, 275.  ,  80.64, ...,   0.  ,   1.  ,   0.  ],
#        ...,
#        [ 13.49, 253.75,  58.47, ...,   0.  ,   1.  ,   0.  ],
#        [ 13.49, 253.75,  58.47, ...,   0.  ,   1.  ,   0.  ],
#        [ 13.49, 253.75,  58.47, ...,   0.  ,   1.  ,   0.  ]])

# %%
X_train, X_test, y_train, y_test = train_test_split(
    train_data[:,:-3], train_data[:,-3:], test_size=0.33, random_state=42)

# %% [markdown]
# Criando modelos

# %%
w0 = np.random.randint(low=-1,high=1, size=18,)
reg = 0.1

stepsize = 0.1
n_steps = 1000

# %%
model = SimpleLogisticRegression

# %%
# Criando num primeiro momento os modelos iguais
lm_0 = model(learning_rate=0.01, n_iterations=500, reg=reg)
lm_1 = model(learning_rate=0.01, n_iterations=500, reg=reg)
lm_2 = model(learning_rate=0.01, n_iterations=500, reg=reg)

y_train_0 = np.delete(y_train, [-1, -2], 1)
y_train_1 = np.delete(y_train, [-1, -3], 1)
y_train_2 = np.delete(y_train, [-2, -3], 1)

# Treinando modelos
lm_0.train(X=X_train, y=y_train_0[:,-1]) 
lm_1.train(X=X_train, y=y_train_1[:,-1]) 
lm_2.train(X=X_train, y=y_train_2[:,-1])
# Out:
# /Users/rafaelapinter/Library/Mobile Documents/com~apple~CloudDocs/1.UdeM/github-projects/extreme-weather-events-ift6380/notebooks/logistic_model.py:87: RuntimeWarning: overflow encountered in exp
#   self.bias = None

# %%
# Criando num primeiro momento os modelos iguais
lm_0 = model(learning_rate=0.01, n_iterations=500, reg=reg)
lm_1 = model(learning_rate=0.01, n_iterations=500, reg=reg)
lm_2 = model(learning_rate=0.01, n_iterations=500, reg=reg)

y_train_0 = np.delete(y_train, [-1, -2], 1)[:,-1]
y_train_1 = np.delete(y_train, [-1, -3], 1)[:,-1]
y_train_2 = np.delete(y_train, [-2, -3], 1)[:,-1]

# Treinando modelos
lm_0.train(X=X_train, y=y_train_0) 
lm_1.train(X=X_train, y=y_train_1) 
lm_2.train(X=X_train, y=y_train_2)
# Out:
# /Users/rafaelapinter/Library/Mobile Documents/com~apple~CloudDocs/1.UdeM/github-projects/extreme-weather-events-ift6380/notebooks/logistic_model.py:87: RuntimeWarning: overflow encountered in exp

# %%
# Treinando modelos
ypred0 = lm_0.predict(X=X_test) 
ypred1 = lm_1.predict(X=X_test) 
ypred2 = lm_2.predict(X=X_test)

# %%
print("Value predicted for model 0: ", np.unique(ypred0))
print("Value predicted for model 1: ", np.unique(ypred1))
print("Value predicted for model 2: ", np.unique(ypred2))
# Out:
# Value predicted for model 0:  [1]
# Value predicted for model 1:  [0]
# Value predicted for model 2:  [0]

# %%
print("accuracy of lm_0", lm_0.accuracy(X=X_train, y=y_train_0))
print("accuracy of lm_1", lm_1.accuracy(X=X_train, y=y_train_1))
print("accuracy of lm_2", lm_2.accuracy(X=X_train, y=y_train_2))
# Out:
# accuracy of lm_0 0.785287938910934
# accuracy of lm_1 0.958418086631765
# accuracy of lm_2 0.826869852279169

# %%
y_test_0 = np.delete(y_test, [-1, -2], 1)[:,-1]
y_test_1 = np.delete(y_test, [-1, -3], 1)[:,-1]
y_test_2 = np.delete(y_test, [-2, -3], 1)[:,-1]

# %% [markdown]
# test

# %% [markdown]
# ---

# %% [markdown]
# My implt

# %%
class LogisticRegression:
    
    def __init__(self, learning_rate=0.01, num_iterations=1000):
        self.learning_rate = learning_rate
        self.num_iterations = num_iterations
        self.weights = None
        self.bias = None
    
    def sigmoid(self, z):
        return 1 / (1 + np.exp(-z))
    
    def fit(self, X, y):
        num_samples, num_features = X.shape
        
        # Initialize weights and bias
        self.weights = np.zeros(num_features)
        self.bias = 0
        
        for _ in range(self.num_iterations):
            # Compute model prediction
            linear_model = np.dot(X, self.weights) + self.bias
            predictions = self.sigmoid(linear_model)
            
            # Compute gradients
            dw = (1 / num_samples) * np.dot(X.T, (predictions - y))
            db = (1 / num_samples) * np.sum(predictions - y)
            
            # Update weights and bias
            self.weights -= self.learning_rate * dw
            self.bias -= self.learning_rate * db
    
    def predict(self, X):
        linear_model = np.dot(X, self.weights) + self.bias
        predictions = self.sigmoid(linear_model)
        y_pred_class = [1 if i > 0.5 else 0 for i in predictions]
        return y_pred_class

# %%
classifier = LogisticRegression(learning_rate=0.01, num_iterations=1000)
classifier.fit(X_train, y_train_2)
predictions = classifier.predict(X_test)

print(predictions)
# Out:
# /var/folders/hw/4hw4rbpn1h3fl_fsrpw80hd80000gn/T/ipykernel_19589/1689321569.py:10: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-z))
# ...
