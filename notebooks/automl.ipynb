# %% [markdown]
# # Implemening AutoML

# %%
import pandas as pd
from pycaret.classification import compare_models, setup, ClassificationExperiment, plot_model

# %%
label_col = "Label"

# %%
data = pd.read_csv("../data/train.csv")

# %%
drop_cols = [
    "time",
    "SNo"
]
data = data.drop(drop_cols, axis=1)

# %% [markdown]
# Pycaret

# %%
s = setup(data, target = label_col, session_id = 123)
# Out:
# <style type="text/css">
# #T_22f51_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_22f51">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22f51_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_22f51_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22f51_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_22f51_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_22f51_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_22f51_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_22f51_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_22f51_row1_col1" class="data row1 col1" >Label</td>
#     </tr>
#     <tr>
#       <th id="T_22f51_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
exp = ClassificationExperiment()

# %%
exp.setup(data, target = label_col, session_id = 123)
# Out:
# <style type="text/css">
# #T_cf9bf_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_cf9bf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf9bf_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_cf9bf_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf9bf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cf9bf_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_cf9bf_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_cf9bf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cf9bf_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_cf9bf_row1_col1" class="data row1 col1" >Label</td>
#     </tr>
#     <tr>
#       <th id="T_cf9bf_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_fb183 th {
#   text-align: left;
# }
# ...

# %%
best
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=123, reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#                subsample_for_bin=200000, subsample_freq=0)

# %%
plot_model(best, plot = 'confusion_matrix')

# %%
plot_model(best, plot = 'auc')

# %%
plot_model(best, plot = 'feature')
