# %% [markdown]
# # Support Vector Machines

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.metrics import accuracy_score, confusion_matrix
from datetime import datetime

import matplotlib.pyplot as plt
import numpy as np

import pandas as pd

# %%
raw_train_data = "../../data/train.csv"
raw_test_data = "../../data/test.csv"

train_data = pd.read_csv(raw_train_data)
test_data = pd.read_csv(raw_test_data)

# %%
train_data
# Out:
#          SNo        lat       lon        TMQ       U850       V850       UBOT  \
# 0          1  21.707953  275.0000  78.909431 -58.805229  36.200672 -58.260475
# 1          2  21.707953  275.0000  78.909431 -58.805229  36.200672 -58.260475
# 2          3  21.473272  275.0000  80.641357 -42.340290  58.060246 -56.400234
# 3          4  21.473272  275.0000  80.641357 -42.340290  58.060246 -56.400234
# 4          5  21.707953  275.3125  76.891205 -45.996342  42.691631 -48.993065
# ...      ...        ...       ...        ...        ...        ...        ...
# 44755  44756  13.494133  253.7500  58.471558  26.397322   5.664860  30.215387
# 44756  44757  13.494133  253.7500  58.471558  26.397322   5.664860  30.215387
# 44757  44758  13.494133  253.7500  58.471558  26.397322   5.664860  30.215387
# 44758  44759  13.494133  253.7500  58.471558  26.397322   5.664860  30.215387
# 44759  44760  13.494133  253.7500  58.471558  26.397322   5.664860  30.215387
#
#             VBOT    QREFHT           PS  ...        T200        T500  \
# 0      -0.722955  0.022321  97497.79688  ...  227.119232  273.045563
# 1      -0.722955  0.022321  97497.79688  ...  227.119232  273.045563
# 2      26.484743  0.022204  96611.60156  ...  229.172897  273.580810
# 3      26.484743  0.022204  96611.60156  ...  229.172897  273.580810
# 4      10.246445  0.022328  98168.55469  ...  224.642563  272.152283
# ...          ...       ...          ...  ...         ...         ...
# 44755   1.547393  0.021974  98739.55469  ...  217.845352  272.109589
# 44756   1.547393  0.021974  98739.55469  ...  217.845352  272.109589
# 44757   1.547393  0.021974  98739.55469  ...  217.845352  272.109589
# 44758   1.547393  0.021974  98739.55469  ...  217.845352  272.109589
# 44759   1.547393  0.021974  98739.55469  ...  217.845352  272.109589
#
#               PRECT          TS      TREFHT      Z1000         Z200  \
# 0      1.390000e-05  302.350861  300.026764  66.339836  12400.22754
# 1      1.390000e-05  302.350861  300.026764  66.339836  12400.22754
# 2      1.440000e-05  302.350861  299.798828  66.165573  12371.33203
# 3      1.440000e-05  302.350861  299.798828  66.165573  12371.33203
# 4      9.890000e-06  302.462708  300.160187  66.880089  12386.88574
# ...             ...         ...         ...        ...          ...
# 44755  1.120000e-07  301.878662  300.574646  66.438522  12340.96973
# 44756  1.120000e-07  301.878662  300.574646  66.438522  12340.96973
# 44757  1.120000e-07  301.878662  300.574646  66.438522  12340.96973
# 44758  1.120000e-07  301.878662  300.574646  66.438522  12340.96973
# 44759  1.120000e-07  301.878662  300.574646  66.438522  12340.96973
#
#             ZBOT      time  Label
# 0      66.241585  20031024      1
# 1      66.241585  20031024      1
# 2      66.165268  20031024      1
# 3      66.165268  20031024      1
# 4      66.275246  20031024      1
# ...          ...       ...    ...
# 44755  66.438522  20011207      1
# 44756  66.438522  20011207      0
# 44757  66.438522  20011207      1
# 44758  66.438522  20011207      1
# 44759  66.438522  20011207      1
#
# [44760 rows x 21 columns]

# %%
# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(
    train_data.drop("Label", axis=1), train_data.Label, test_size=0.3, random_state=42
)

# Standardize the data
scaler = StandardScaler().fit(X_train)
X_train_std = scaler.transform(X_train)
X_test_std = scaler.transform(X_test)

class_weights = {0: 1, 1: 16, 2: 5.3}  # for class 0  # for class 1  # for class 2

# Define a pipeline with feature selection and SVC
estimator = SVC()
selector = SelectKBest(f_classif, k='all')  # 'all' keeps all features. Adjust as needed.
pipeline = Pipeline([
    ('feature_selection', selector),
    ('classifier', estimator)
])

# %%
# Define the hyperparameter grid to search
param_grid = {
    'classifier__C': [0.1, 1],
    'classifier__kernel': ['linear', 'rbf'],
    'classifier__gamma': ['scale', 'auto', 0.1, 1],
    'classifier__class_weight': [class_weights, 'balanced'],
    'feature_selection__k': [5,7,9,11]
}

# Create the grid search with cross-validation using the pipeline
clf = GridSearchCV(pipeline, param_grid, cv=5, verbose=2, n_jobs=-1)

# Fit the model
clf.fit(X_train_std, y_train)
# Out:
# Fitting 5 folds for each of 128 candidates, totalling 640 fits
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=5; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=5; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=5; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=5; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=5; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=7; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=7; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=7; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=7; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=7; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=9; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=9; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=9; total time= 1.2min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=9; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=9; total time= 1.2min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=11; total time= 1.2min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=11; total time= 1.4min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=11; total time= 1.4min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=11; total time= 1.4min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=11; total time= 1.4min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=5; total time= 1.6min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=5; total time= 1.6min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=5; total time= 1.6min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=5; total time= 1.6min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=5; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=7; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=7; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=7; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=7; total time= 1.0min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=7; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=9; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=9; total time= 1.0min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=9; total time= 1.0min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=9; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=9; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=11; total time= 1.2min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=11; total time= 1.3min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=11; total time= 1.3min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=11; total time= 1.3min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=11; total time= 1.3min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=5; total time= 1.0min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=5; total time= 1.0min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=5; total time= 1.0min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=5; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=5; total time= 1.2min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=7; total time= 1.4min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=7; total time= 1.3min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=7; total time= 1.3min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=7; total time= 1.3min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=7; total time= 1.3min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=9; total time= 1.4min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=9; total time= 1.3min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=9; total time= 1.2min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=9; total time= 1.3min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=9; total time= 1.3min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=11; total time= 1.4min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=11; total time= 1.4min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=11; total time= 1.5min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=11; total time= 1.4min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=11; total time= 1.4min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=5; total time= 1.3min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=5; total time= 1.2min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=5; total time= 1.2min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=5; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=5; total time= 1.0min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=7; total time= 1.0min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=7; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=7; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=7; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=7; total time= 1.2min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=9; total time= 1.2min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=9; total time= 1.2min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=9; total time= 1.0min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=9; total time= 1.0min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=9; total time=  58.4s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=11; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=11; total time= 1.0min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=5; total time=  36.9s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=11; total time= 1.0min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=11; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=11; total time= 1.0min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=5; total time=  38.2s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=5; total time=  38.1s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=5; total time=  39.9s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=5; total time=  43.1s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=7; total time=  48.9s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=7; total time=  49.0s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=7; total time=  48.2s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=7; total time=  47.1s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=7; total time=  47.7s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=9; total time=  49.9s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=9; total time=  47.7s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=9; total time=  48.6s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=9; total time=  48.4s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=9; total time=  49.8s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=11; total time=  55.4s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=11; total time=  54.2s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=11; total time=  54.5s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=11; total time=  52.7s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=11; total time=  50.4s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=5; total time=  56.3s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=5; total time=  55.7s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=5; total time=  53.1s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=5; total time=  51.9s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=5; total time=  51.8s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=7; total time=  51.1s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=7; total time=  50.4s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=7; total time=  50.6s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=7; total time=  49.6s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=7; total time=  52.0s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=9; total time=  51.4s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=9; total time=  52.0s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=9; total time=  51.2s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=9; total time=  52.1s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=9; total time=  51.1s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=11; total time=  55.3s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=11; total time=  56.1s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=5; total time=  35.4s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=5; total time=  35.5s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=5; total time=  35.3s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=5; total time=  34.5s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=11; total time=  58.5s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=11; total time=  57.9s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=11; total time=  59.0s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=5; total time=  38.8s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=7; total time=  42.8s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=7; total time=  43.3s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=7; total time=  43.0s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=7; total time=  44.2s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=7; total time=  45.6s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=9; total time=  47.1s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=9; total time=  48.5s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=9; total time=  48.4s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=9; total time=  49.0s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=9; total time=  50.1s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=11; total time=  55.9s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=11; total time=  53.8s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=11; total time=  53.3s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=11; total time=  51.8s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=11; total time=  49.6s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=5; total time=  50.9s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=5; total time=  49.1s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=5; total time=  48.2s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=5; total time=  46.0s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=5; total time=  46.3s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=7; total time=  42.8s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=7; total time=  43.3s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=7; total time=  44.9s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=7; total time=  48.1s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=7; total time=  50.3s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=9; total time=  53.1s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=9; total time=  52.7s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=9; total time=  58.0s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=9; total time=  56.6s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=9; total time=  57.8s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=11; total time=  59.1s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=11; total time= 1.0min
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=5; total time=  36.7s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=5; total time=  36.3s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=5; total time=  36.2s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=11; total time= 1.0min
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=11; total time=  59.2s
# [CV] END classifier__C=0.1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=11; total time=  56.8s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=5; total time=  32.8s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=5; total time=  35.6s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=7; total time=  39.3s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=7; total time=  40.0s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=7; total time=  40.0s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=7; total time=  41.6s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=7; total time=  43.1s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=9; total time=  47.5s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=9; total time=  47.6s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=9; total time=  49.1s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=9; total time=  49.0s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=9; total time=  49.0s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=11; total time=  53.7s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=11; total time=  51.6s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=11; total time=  50.0s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=11; total time=  46.2s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=linear, feature_selection__k=11; total time=  46.8s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=5; total time=  55.1s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=5; total time=  52.8s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=5; total time=  54.7s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=5; total time=  52.0s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=5; total time=  52.1s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=7; total time=  52.4s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=7; total time=  52.1s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=7; total time=  51.6s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=7; total time=  50.9s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=7; total time=  51.9s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=9; total time=  54.3s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=9; total time=  51.8s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=9; total time=  53.6s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=9; total time=  51.7s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=9; total time=  52.1s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=11; total time=  56.7s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=5; total time=  34.4s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=5; total time=  36.4s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=5; total time=  34.7s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=5; total time=  34.2s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=11; total time= 1.0min
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=11; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=11; total time= 1.0min
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=scale, classifier__kernel=rbf, feature_selection__k=11; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=5; total time=  34.2s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=7; total time=  39.8s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=7; total time=  39.9s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=7; total time=  40.0s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=7; total time=  42.7s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=7; total time=  47.2s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=9; total time=  50.3s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=9; total time=  50.7s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=9; total time=  51.1s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=9; total time=  48.6s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=9; total time=  49.3s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=11; total time=  53.0s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=11; total time=  50.5s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=11; total time=  47.0s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=11; total time=  45.1s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=11; total time=  43.6s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=5; total time=  55.8s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=5; total time=  52.3s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=5; total time=  52.3s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=5; total time=  50.9s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=5; total time=  51.6s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=7; total time=  53.0s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=7; total time=  51.6s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=7; total time=  53.8s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=7; total time=  54.8s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=9; total time=  54.5s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=7; total time=  56.4s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=9; total time=  56.3s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=9; total time=  54.7s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=9; total time=  56.5s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=9; total time= 1.0min
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=11; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=5; total time=  41.4s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=11; total time= 1.2min
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=5; total time=  40.0s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=5; total time=  38.5s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=11; total time= 1.2min
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=11; total time= 1.2min
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=5; total time=  37.5s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=11; total time= 1.2min
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=5; total time=  41.1s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=7; total time=  46.9s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=7; total time=  47.1s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=7; total time=  48.4s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=7; total time=  47.6s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=7; total time=  48.1s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=9; total time=  49.0s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=9; total time=  49.4s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=9; total time=  47.6s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=9; total time=  46.6s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=9; total time=  46.9s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=11; total time=  51.5s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=11; total time=  51.1s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=11; total time=  50.9s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=11; total time=  48.6s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=11; total time=  50.9s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=5; total time= 1.0min
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=5; total time=  56.3s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=5; total time=  57.8s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=5; total time=  53.5s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=5; total time=  53.6s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=7; total time=  54.8s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=7; total time=  53.2s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=7; total time=  53.4s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=7; total time= 1.0min
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=7; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=9; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=9; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=9; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=9; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=9; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=11; total time= 1.2min
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=11; total time= 1.1min
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=5; total time=  42.8s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=5; total time=  43.6s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=5; total time=  44.7s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=11; total time= 1.2min
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=5; total time=  44.0s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=11; total time= 1.3min
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=11; total time= 1.3min
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=5; total time=  43.0s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=7; total time=  46.3s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=7; total time=  47.9s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=7; total time=  47.3s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=7; total time=  47.2s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=7; total time=  47.9s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=9; total time=  49.4s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=9; total time=  51.0s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=9; total time=  48.6s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=9; total time=  49.3s
# [CV] END classifier__C=0.1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=9; total time=  49.7s
# ...
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=linear, feature_selection__k=11; total time=  55.6s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=5; total time= 1.0min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=5; total time=  58.7s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=5; total time=  55.2s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=5; total time=  51.4s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=5; total time=  52.5s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=7; total time=  51.3s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=7; total time=  51.1s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=7; total time=  50.4s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=7; total time=  48.1s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=7; total time=  49.8s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=9; total time=  49.9s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=9; total time=  50.0s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=9; total time=  50.8s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=9; total time=  50.3s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=9; total time=  50.1s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=11; total time=  54.0s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=11; total time=  55.8s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=11; total time=  53.2s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=11; total time=  53.7s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=5; total time=  40.1s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=5; total time=  40.7s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=5; total time=  44.6s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=5; total time=  42.1s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=auto, classifier__kernel=rbf, feature_selection__k=11; total time=  59.4s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=5; total time=  47.0s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=7; total time=  55.1s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=7; total time=  55.0s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=7; total time=  52.4s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=7; total time=  50.5s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=7; total time=  53.8s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=9; total time=  58.0s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=9; total time=  58.5s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=9; total time=  55.6s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=9; total time=  58.3s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=9; total time=  57.9s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=11; total time= 1.1min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=11; total time= 1.1min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=11; total time=  58.3s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=11; total time= 1.0min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=linear, feature_selection__k=11; total time=  59.7s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=5; total time= 1.0min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=5; total time=  56.4s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=5; total time=  55.8s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=5; total time=  52.6s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=5; total time=  56.2s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=7; total time=  51.5s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=7; total time=  54.8s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=7; total time=  54.6s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=7; total time= 1.0min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=7; total time= 1.1min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=9; total time= 1.2min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=9; total time= 1.2min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=9; total time= 1.2min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=9; total time= 1.2min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=9; total time= 1.1min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=11; total time= 1.2min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=11; total time= 1.1min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=11; total time= 1.0min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=5; total time=  50.1s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=11; total time= 1.1min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=5; total time=  50.4s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=0.1, classifier__kernel=rbf, feature_selection__k=11; total time= 1.2min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=5; total time=  51.2s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=5; total time=  55.5s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=5; total time=  58.4s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=7; total time= 1.1min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=7; total time= 1.1min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=7; total time= 1.1min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=7; total time= 1.0min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=7; total time= 1.0min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=9; total time= 1.1min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=9; total time= 1.1min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=9; total time= 1.1min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=9; total time= 1.1min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=9; total time= 1.4min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=11; total time= 1.8min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=11; total time= 1.8min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=11; total time= 1.8min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=11; total time= 1.9min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=linear, feature_selection__k=11; total time= 1.9min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=5; total time= 1.6min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=5; total time= 1.6min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=5; total time= 1.4min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=7; total time=  57.5s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=5; total time= 1.1min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=5; total time= 1.1min
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=7; total time=  54.1s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=7; total time=  54.6s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=7; total time=  54.7s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=7; total time=  54.7s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=9; total time=  55.0s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=9; total time=  53.6s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=9; total time=  54.4s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=9; total time=  55.4s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=9; total time=  51.7s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=11; total time=  48.6s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=11; total time=  47.4s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=11; total time=  36.9s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=11; total time=  27.6s
# [CV] END classifier__C=1, classifier__class_weight=balanced, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=11; total time=  23.5s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('feature_selection',
#                                         SelectKBest(k='all')),
#                                        ('classifier', SVC())]),
#              n_jobs=-1,
#              param_grid={'classifier__C': [0.1, 1],
#                          'classifier__class_weight': [{0: 1, 1: 16, 2: 5.3},
#                                                       'balanced'],
#                          'classifier__gamma': ['scale', 'auto', 0.1, 1],
#                          'classifier__kernel': ['linear', 'rbf'],
#                          'feature_selection__k': [5, 7, 9, 11]},
#              verbose=2)

# %%
# Print the best hyperparameters
print("Best hyperparameters:", clf.best_params_)

# Test the model
accuracy = clf.score(X_test_std, y_test)
print(f"Test accuracy with best hyperparameters: {accuracy:.2f}")
# Out:
# Best hyperparameters: {'classifier__C': 1, 'classifier__class_weight': {0: 1, 1: 16, 2: 5.3}, 'classifier__gamma': 1, 'classifier__kernel': 'rbf', 'feature_selection__k': 11}
# Test accuracy with best hyperparameters: 0.85

# %%
param_grid = {'classifier__C': [1], 'classifier__class_weight': [{0: 1, 1: 16, 2: 5.3}], 'classifier__gamma': [1], 'classifier__kernel': ['rbf'], 'feature_selection__k': [11]}

# Create the grid search with cross-validation using the pipeline
clf = GridSearchCV(pipeline, param_grid, cv=2, verbose=2, n_jobs=-1)

# Fit the model
clf.fit(X_train_std, y_train)
# Out:
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [CV] END classifier__C=1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=11; total time=  14.6s
# [CV] END classifier__C=1, classifier__class_weight={0: 1, 1: 16, 2: 5.3}, classifier__gamma=1, classifier__kernel=rbf, feature_selection__k=11; total time=  15.7s
# GridSearchCV(cv=2,
#              estimator=Pipeline(steps=[('feature_selection',
#                                         SelectKBest(k='all')),
#                                        ('classifier', SVC())]),
#              n_jobs=-1,
#              param_grid={'classifier__C': [1],
#                          'classifier__class_weight': [{0: 1, 1: 16, 2: 5.3}],
#                          'classifier__gamma': [1],
#                          'classifier__kernel': ['rbf'],
#                          'feature_selection__k': [11]},
#              verbose=2)

# %%
confusion_matrix(y_test, clf.predict(X_test))
# Out:
# /Users/rafaelapinter/miniconda3/envs/dc1-env/lib/python3.9/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectKBest was fitted without feature names
#   warnings.warn(
# array([[10580,     0,     0],
#        [  532,     0,     0],
#        [ 2316,     0,     0]])

# %%
scaler = StandardScaler().fit(test_data)
X_test = scaler.transform(test_data)

# %%
test_data['Label'].value_counts(normalize=True)
# Out:
# 0    0.671899
# 2    0.245640
# 1    0.082461
# Name: Label, dtype: float64

# %%
pd.Series(clf.predict(X_test)).value_counts(normalize=True)
# Out:
# /Users/rafaelapinter/miniconda3/envs/dc1-env/lib/python3.9/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectKBest was fitted without feature names
#   warnings.warn(
# 0    1.0
# dtype: float64

# %%
test_data['Label'] = clf.predict(X_test)
submition = test_data[["SNo", "Label"]]
# submition.drop("index", axis=1, inplace=True)
submition.to_csv(f"predictions_{datetime.now()}_svm.csv", index=False)

# %%
# Extract information from cv_results_
mean_test_score = clf.cv_results_["mean_test_score"]  # Mean test accuracy
std_test_score = clf.cv_results_[
    "std_test_score"
]  # Standard deviation of test accuracy
mean_train_score = clf.cv_results_[
    "mean_train_score"
]  # Mean training accuracy (if return_train_score=True)
std_train_score = clf.cv_results_[
    "std_train_score"
]  # Standard deviation of training accuracy

# Generate x-axis labels (e.g., hyperparameter combinations)
params = [str(p) for p in clf.cv_results_["params"]]

# Plot validation errors
plt.figure(figsize=(10, 5))
plt.errorbar(
    np.arange(len(mean_test_score)),
    1 - mean_test_score,
    yerr=std_test_score,
    marker="o",
    label="Validation Error",
    capsize=5,
)
plt.errorbar(
    np.arange(len(mean_train_score)),
    1 - mean_train_score,
    yerr=std_train_score,
    marker="x",
    label="Training Error",
    capsize=5,
)
plt.xticks(np.arange(len(mean_test_score)), params, rotation=45, ha="right")
plt.ylabel("Error")
plt.legend()
plt.title("Validation and Training Errors for Different Hyperparameters")
plt.tight_layout()
plt.show()

# Plot accuracies
plt.figure(figsize=(10, 5))
plt.errorbar(
    np.arange(len(mean_test_score)),
    mean_test_score,
    yerr=std_test_score,
    marker="o",
    label="Validation Accuracy",
    capsize=5,
)
plt.errorbar(
    np.arange(len(mean_train_score)),
    mean_train_score,
    yerr=std_train_score,
    marker="x",
    label="Training Accuracy",
    capsize=5,
)
plt.xticks(np.arange(len(mean_test_score)), params, rotation=45, ha="right")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Validation and Training Accuracies for Different Hyperparameters")
plt.tight_layout()
plt.show()
